# %%
import pandas as pd
import re

# %% [markdown]
# ## Creating Default Flags List

# %%
# A list of lists: the default values of every flag available in PyRate
defaults = [['seed', '-1'], ['useCPPlib', '1'], ['cite', 'False'], ['input_data', '[]'], ['j', '1'],
['trait', '1'], ['logT', '0'], ['N', '-1'], ['wd', '""'], ['out', '""'], ['singleton', '0'],
['frac_sampled_singleton', '0'], ['rescale', '1'], ['translate', '0'], ['d', '""'], ['clade', '-1'], ['trait_file', '""'],
['restore_mcmc', '""'], ['filter', '[inf, 0]'], ['filter_taxa', '""'], ['initDiv', '0'], ['PPmodeltest', 'False'], ['log_marginal_rates', '-1'],
['log_sp_q_rates', 'False'], ['drop_zero', '0'], ['drop_internal', 'False'], ['tree', '""'], ['sampling', '1.0'], ['bdc', 'False'],
['eqr', 'False'], ['plot', '""'], ['plot2', '""'], ['plot3', '""'], ['plotRJ', '""'], ['plotBDNN', '""'],
['plotBDNN_groups', '""'], ['plotBDNN_effects', '""'], ['plotBDNN_transf_features', '""'], ['BDNN_groups', '{}'], ['BDNN_interaction', '""'], ['BDNN_interaction_fix', 'False'],
['n_prior', '100000'], ['plotQ', '""'], ['grid_plot', '0'], ['root_plot', '0'], ['min_age_plot', '0'], ['tag', '""'],
['ltt', '0'], ['mProb', '""'], ['BF', '[]'], ['data_info', 'False'], ['SE_stats', '[]'], ['ginput', '""'],
['combLog', '""'], ['combLogRJ', '""'], ['combBDNN', '""'], ['resample', '0'], ['col_tag', '[]'], ['check_names', '""'],
['reduceLog', '""'], ['n', '10000000'], ['s', '1000'], ['p', '1000'], ['b', '0'], ['fast_burnin', '0'],
['thread', '[0, 0]'], ['A', '4'], ['use_DA', 'False'], ['r', '1'], ['t', '0.03'], ['sw', '100'],
['M', '10'], ['B', '1'], ['T', '1.0'], ['S', '1000'], ['k', '10'], ['a', '0.3'],
['dpp_f', '500'], ['dpp_hp', '2.0'], ['dpp_eK', '2.0'], ['dpp_grid', '1.5'], ['dpp_nB', '0'], ['rj_pr', '1'],
['rj_Ga', '1.5'], ['rj_Gb', '3.0'], ['rj_beta', '10'], ['rj_dm', '0'], ['rj_bd_shift', '0.5'], ['se_gibbs', 'False'],
['pL', '[1.1, 1.1]'], ['pM', '[1.1, 1.1]'], ['pP', '[1.5, 1.1]'], ['pS', '2.5'], ['pC', '1'], ['cauchy', '[-1, -1]'],
['min_dt', '1.0'], ['mHPP', 'False'], ['mL', '1'], ['mM', '1'], ['mC', 'False'], ['mCov', '0'],
['mG', 'False'], ['mPoiD', 'False'], ['mBirth', '-1'], ['mDeath', 'False'], ['mBDI', '-1'], ['ncat', '4'],
['fixShift', '""'], ['qShift', '""'], ['fixSE', '""'], ['ADE', '0'], ['discrete', 'False'], ['twotrait', 'False'],
['bound', '[inf, 0]'], ['partialBD', 'False'], ['edgeShift', '[inf, 0]'], ['qFilter', '1'], ['FBDrange', '0'], ['BDNNmodel', '0'],
['BDNNnodes', '[16, 8]'], ['BDNNfadlad', '0'], ['BDNNtimetrait', '-1'], ['BDNNconstbaseline', '1'], ['BDNNoutputfun', '1'], ['BDNNactfun', '5'],
['BDNNprior', '1'], ['BDNNreg', '[1.0]'], ['BDNNblockmodel', 'False'], ['BDNNtimevar', "['']"], ['BDNNtimevar_q', '""'], ['BDNNads', '-1.0'],
['BDNNpath_taxon_time_tables', "['', '']"], ['BDNNexport_taxon_time_tables', 'False'], ['BDNNupdate_se_f', '[0.6]'], ['BDNNupdate_f', '[0.1]'], 
['BDNNdd', 'False'], ['BDNNpklfile', '""'], ['BDNN_pred_importance', '""'], ['BDNN_nsim_expected_cv', '100'], ['BDNN_pred_importance_interaction', 'True'], 
['BDNN_pred_importance_window_size', '[-1.0]'], ['BDNN_pred_importance_nperm', '100'], ['BDNN_mean_shap_per_group', 'False'],
['edge_indicator', 'False'], ['tT', '1.0'], ['nT', '5'], ['tQ', '[1.2, 1.2]'], ['tR', '1.2'], ['tS', '1.0'],
['fR', '0.5'], ['fS', '0.7'], ['fQ', '0.5'], ['tC', '[0.2, 0.2, 0.15]'], ['fU', '[0.02, 0.18, 0.08]'], ['multiR', '1'],
['tHP', '[1.2, 1.2]']]

# Default values that are = double quotes are acutally outputted as single quotes in sum.txt, so I need to change the "" to '' in defaults
for list in defaults:
    if list[1] == '""':
        list[1] = "''"

defaults
# Out:
# [['seed', '-1'],
#  ['useCPPlib', '1'],
#  ['cite', 'False'],
#  ['input_data', '[]'],
#  ['j', '1'],
#  ['trait', '1'],
#  ['logT', '0'],
#  ['N', '-1'],
#  ['wd', "''"],
#  ['out', "''"],
#  ['singleton', '0'],
#  ['frac_sampled_singleton', '0'],
#  ['rescale', '1'],
#  ['translate', '0'],
#  ['d', "''"],
#  ['clade', '-1'],
#  ['trait_file', "''"],
#  ['restore_mcmc', "''"],
#  ['filter', '[inf, 0]'],
#  ['filter_taxa', "''"],
#  ['initDiv', '0'],
#  ['PPmodeltest', 'False'],
#  ['log_marginal_rates', '-1'],
#  ['log_sp_q_rates', 'False'],
#  ['drop_zero', '0'],
#  ['drop_internal', 'False'],
#  ['tree', "''"],
#  ['sampling', '1.0'],
#  ['bdc', 'False'],
#  ['eqr', 'False'],
#  ['plot', "''"],
#  ['plot2', "''"],
#  ['plot3', "''"],
#  ['plotRJ', "''"],
#  ['plotBDNN', "''"],
#  ['plotBDNN_groups', "''"],
#  ['plotBDNN_effects', "''"],
#  ['plotBDNN_transf_features', "''"],
#  ['BDNN_groups', '{}'],
#  ['BDNN_interaction', "''"],
#  ['BDNN_interaction_fix', 'False'],
# ...

# %%
# Version directly from PyRate (default values are slightly different, and do not match what is outputted in the *sum.txts)
# For example, default value may be .2, but sum.txt value is 0.2
# # In addition, double quotes in default are acutally single quotes in sum.txt, so they are changed in defaults above 
# Additional edits like removing spaces was needed. Compare the above 

# A list of lists: the default values of every flag available in PyRate
# defaults = [['seed', '-1'], ['useCPPlib', '1'], ['cite', 'False'], ['input_data', '[]'], ['j', '1'],
# ['trait', '1'], ['logT', '0'], ['N', '-1'], ['wd', '""'], ['out', '""'], ['singleton', '0'],
# ['frac_sampled_singleton', '0'], ['rescale', '1'], ['translate', '0'], ['d', '""'], ['clade', '-1'], ['trait_file', '""'],
# ['restore_mcmc', '""'], ['filter', '[inf,0]'], ['filter_taxa', '""'], ['initDiv', '0'], ['PPmodeltest', 'False'], ['log_marginal_rates', '-1'],
# ['log_sp_q_rates', 'False'], ['drop_zero', '0'], ['drop_internal', 'False'], ['tree', '""'], ['sampling', '1.'], ['bdc', 'False'],
# ['eqr', 'False'], ['plot', '""'], ['plot2', '""'], ['plot3', '""'], ['plotRJ', '""'], ['plotBDNN', '""'],
# ['plotBDNN_groups', '""'], ['plotBDNN_effects', '""'], ['plotBDNN_transf_features', '""'], ['BDNN_groups', '{}'], ['BDNN_interaction', '""'], ['BDNN_interaction_fix', 'False'],
# ['n_prior', '100000'], ['plotQ', '""'], ['grid_plot', '0'], ['root_plot', '0'], ['min_age_plot', '0'], ['tag', '""'],
# ['ltt', '0'], ['mProb', '""'], ['BF', '[]'], ['data_info', 'False'], ['SE_stats', '[]'], ['ginput', '""'],
# ['combLog', '""'], ['combLogRJ', '""'], ['combBDNN', '""'], ['resample', '0'], ['col_tag', '[]'], ['check_names', '""'],
# ['reduceLog', '""'], ['n', '10000000'], ['s', '1000'], ['p', '1000'], ['b', '0'], ['fast_burnin', '0'],
# ['thread', '[0,0]'], ['A', '4'], ['use_DA', 'False'], ['r', '1'], ['t', '.03'], ['sw', '100'],
# ['M', '10'], ['B', '1'], ['T', '1.0'], ['S', '1000'], ['k', '10'], ['a', '.3'],
# ['dpp_f', '500'], ['dpp_hp', '2.'], ['dpp_eK', '2.'], ['dpp_grid', '1.5'], ['dpp_nB', '0'], ['rj_pr', '1'],
# ['rj_Ga', '1.5'], ['rj_Gb', '3.'], ['rj_beta', '10'], ['rj_dm', '0'], ['rj_bd_shift', '0.5'], ['se_gibbs', 'False'],
# ['pL', '[1.1, 1.1]'], ['pM', '[1.1, 1.1]'], ['pP', '[1.5, 1.1]'], ['pS', '2.5'], ['pC', '1'], ['cauchy', '[-1, -1]'],
# ['min_dt', '1.'], ['mHPP', 'False'], ['mL', '1'], ['mM', '1'], ['mC', 'False'], ['mCov', '0'],
# ['mG', 'False'], ['mPoiD', 'False'], ['mBirth', '-1'], ['mDeath', 'False'], ['mBDI', '-1'], ['ncat', '4'],
# ['fixShift', '""'], ['qShift', '""'], ['fixSE', '""'], ['ADE', '0'], ['discrete', 'False'], ['twotrait', 'False'],
# ['bound', '[np.inf, 0]'], ['partialBD', 'False'], ['edgeShift', '[np.inf, 0]'], ['qFilter', '1'], ['FBDrange', '0'], ['BDNNmodel', '0'],
# ['BDNNnodes', '[16, 8]'], ['BDNNfadlad', '0'], ['BDNNtimetrait', '-1'], ['BDNNconstbaseline', '1'], ['BDNNoutputfun', '1'], ['BDNNactfun', '5'],
# ['BDNNprior', '1'], ['BDNNreg', '[1.0]'], ['BDNNblockmodel', 'False'], ['BDNNtimevar', '""'], ['BDNNtimevar_q', '""'], ['BDNNads', '-1.0'],
# ['BDNNpath_taxon_time_tables', '["", ""]'], ['BDNNexport_taxon_time_tables', 'False'], ['BDNNupdate_se_f', '[0.6]'], ['BDNNupdate_f', '[0.1]'], 
# ['BDNNdd', 'False'], ['BDNNpklfile', '""'], ['BDNN_pred_importance', '""'], ['BDNN_nsim_expected_cv', '100'], ['BDNN_pred_importance_interaction', 'True'], 
# ['BDNN_pred_importance_window_size', '[-1.0]'], ['BDNN_pred_importance_nperm', '100'], ['BDNN_mean_shap_per_group', 'False'],
# ['edge_indicator', 'False'], ['tT', '1.'], ['nT', '5'], ['tQ', '[1.2,1.2]'], ['tR', '1.2'], ['tS', '1.'],
# ['fR', '.5'], ['fS', '.7'], ['fQ', '.5'], ['tC', '[.2, .2, .15]'], ['fU', '[.02, .18, .08]'], ['multiR', '1'],
# ['tHP', '[1.2, 1.2]']]

# defaults_df = pd.DataFrame(defaults, columns=['Key', 'Default Value'])

# %%
defaults_df = pd.DataFrame(defaults, columns=['Key', 'Default Value'])

# %%
len(defaults_df)
# Out:
# 156

# %% [markdown]
# ## Creating Custom Function for Comparing sum.txt with Default Flags

# %%
# # Custom function for taking in the *_sum.txt Namespace, making it into a dataframe, merging it with the defaults_df
# # outputting only the non-default flag values used

# def dataframe(namespace):
#     # Turning the namespace string into a list of strings (splitting by comma followed by a space, followed by a letter, UNLESS followed by "inf")
#     data = re.split(r', (?:inf, )*(?=[a-zA-Z])', namespace)

#     # Split each individual string in the list by "=" into key and value --> list of lists
#     split_data = [item.split('=', 1) for item in data]

#     # Make the list of lists into a DataFrame
#     df = pd.DataFrame(split_data, columns=['Key', 'Value'])

#     # Merge with defaults dataframe
#     df = df.merge(defaults_df, how='outer', on='Key')

#     df['Different'] = df['Value'] != df['Default Value']

#     # Save the DataFrame to a CSV file
#     # df.to_csv(f'{name}_sumtxt.csv', index=False)
    
#     return df[df['Different'] == True]

# %%
# def extract_namespace_content(filepath):
#     """
#     Extracts content between parentheses in 'Namespace=()' from a text file
    
#     Args:
#         filepath (str): Path to the text file
        
#     Returns:
#         str: Content between parentheses, or None if not found
#     """
#     try:
#         with open(filepath, 'r') as file:
#             content = file.read()
            
#         # Use regex to locate and extract content inside "Namespace=()"
#         match = re.search(r'Namespace\((.*?)\)', content)
#         if match:
#             return match.group(1)  # Everything inside the parentheses
#         else:
#             return None  # Return None if the pattern is not found
#     except FileNotFoundError:
#         print(f"File not found: {file_path}")
#         return None
#     except Exception as e:
#         print(f"An error occurred: {e}")
#         return None

# %%
# Combining those two functions above
def sumtxt_extraction(file_path):
    """
    Combines extracting namespace data from a .txt file with converting it into a DataFrame
    that highlights differences from a default DataFrame.

    Args:
        file_path (str): Path to the .txt file.
        defaults_df (pd.DataFrame): DataFrame containing default values for comparison.

    Returns:
        pd.DataFrame: A DataFrame showing rows where the Value differs from the Default Value.
    """
    def extract_namespace_from_txt(file_path):
        """
        Extracts content within 'Namespace=()' from a .txt file. Returns a namespace string
        """
        try:
            with open(file_path, 'r') as file:
                content = file.read()

            # Use regex to locate and extract content inside "Namespace=()"
            match = re.search(r'Namespace\((.*?)\)', content)
            if match:
                return match.group(1)  # Everything inside the parentheses
            else:
                return None  # Return None if the pattern is not found
        except FileNotFoundError:
            print(f"File not found: {file_path}")
            return None
        except Exception as e:
            print(f"An error occurred: {e}")
            return None

    def dataframe(namespace):
        """
        Converts a namespace string into a DataFrame and highlights differences from default values.
        """
        # Turning the namespace string into a list of strings
        data = re.split(r', (?:inf, )*(?=[a-zA-Z])', namespace)

        # Split each individual string in the list by "=" into key and value --> list of lists
        split_data = [item.split('=', 1) for item in data]

        # Make the list of lists into a DataFrame
        df = pd.DataFrame(split_data, columns=['Key', 'Value'])

        # Merge with defaults dataframe
        df = df.merge(defaults_df, how='outer', on='Key')

        df['Different'] = df['Value'] != df['Default Value']

        return df[df['Different'] == True]

    # Process the file to extract namespace content
    namespace_content = extract_namespace_from_txt(file_path)
    if namespace_content:
        # Pass the extracted namespace to the dataframe function
        return dataframe(namespace_content)
    else:
        print("No 'Namespace()' pattern found in the file.")
        return pd.DataFrame()  # Return an empty DataFrame if no namespace is found

# %%
# content = extract_namespace_content('./reptilia/pyrate_mcmc_logs/reptilia_pyrate_1_G_ADE_ADE_sum.txt')
# content

# %%
sumtxt_extraction('./reptilia/pyrate_mcmc_logs/reptilia_pyrate_1_G_ADE_ADE_sum.txt')
# Out:
#             Key                                              Value  \
# 1           ADE                                                  1
# 67           fU                                    [0.02, 0.18, 0]
# 72     fixShift                    './data/Time_bins_ByStages.txt'
# 77   input_data  ['./data/reptilia_processed_data/reptilia_pyra...
# 89           mG                                               True
# 98            n                                          100000000
# 103           p                                               2000
# 120      qShift                    './data/Time_bins_ByStages.txt'
# 133           s                                              10000
# 150   translate                                             -175.0
# 155          wd                                      './reptilia/'
#
#           Default Value  Different
# 1                     0       True
# 67   [0.02, 0.18, 0.08]       True
# 72                   ''       True
# ...

# %%
# rep_bdnn_2 = "seed=-1, useCPPlib=1, cite=False, input_data=['.\\data\\reptilia_processed_data\\reptilia_pyrate_PyRate.py'], j=2, trait=1, logT=0, N=-1, wd='.\\reptilia\\', out='', singleton=0, frac_sampled_singleton=0, rescale=1, translate=175.0, d='', clade=-1, trait_file='', restore_mcmc='', filter=[inf, 0], filter_taxa='', initDiv=0, PPmodeltest=False, log_marginal_rates=-1, log_sp_q_rates=False, drop_zero=0, drop_internal=False, tree='', sampling=1.0, bdc=False, eqr=False, plot='', plot2='', plot3='', plotRJ='', plotBDNN='', plotBDNN_groups='', plotBDNN_effects='', plotBDNN_transf_features='', BDNN_groups={}, BDNN_interaction='', BDNN_interaction_fix=False, n_prior=100000, plotQ='', grid_plot=0, root_plot=0, min_age_plot=0, tag='', ltt=0, mProb='', BF=[], data_info=False, SE_stats=[], ginput='', combLog='', combLogRJ='', combBDNN='', resample=0, col_tag=[], check_names='', reduceLog='', n=100000000, s=10000, p=2000, b=0, fast_burnin=0, thread=[0, 0], A=4, use_DA=False, r=1, t=0.03, sw=100, M=10, B=1, T=1.0, S=1000, k=10, a=0.3, dpp_f=500, dpp_hp=2.0, dpp_eK=2.0, dpp_grid=1.5, dpp_nB=0, rj_pr=1, rj_Ga=1.5, rj_Gb=3.0, rj_beta=10, rj_dm=0, rj_bd_shift=0.5, se_gibbs=False, pL=[1.1, 1.1], pM=[1.1, 1.1], pP=[1.5, 1.1], pS=2.5, pC=1, cauchy=[-1, -1], min_dt=1.0, mHPP=False, mL=1, mM=1, mC=False, mCov=0, mG=True, mPoiD=False, mBirth=-1, mDeath=False, mBDI=-1, ncat=4, fixShift='', qShift='.\\data\\Time_bins_ByStages.txt', fixSE='', ADE=0, discrete=False, twotrait=False, bound=[inf, 0], partialBD=False, edgeShift=[inf, 0], qFilter=1, FBDrange=0, BDNNmodel=1, BDNNnodes=[8, 4], BDNNfadlad=0, BDNNtimetrait=-1, BDNNconstbaseline=1, BDNNoutputfun=1, BDNNactfun=5, BDNNprior=1, BDNNreg=[1.0], BDNNblockmodel=False, BDNNtimevar=[''], BDNNtimevar_q='', BDNNads=-1.0, BDNNpath_taxon_time_tables=['', ''], BDNNexport_taxon_time_tables=False, BDNNupdate_se_f=[0.6], BDNNupdate_f=[0.05, 0.05, 0.25], BDNNdd=False, BDNNpklfile='', BDNN_pred_importance='', BDNN_nsim_expected_cv=100, BDNN_pred_importance_interaction=True, BDNN_pred_importance_window_size=[-1.0], BDNN_pred_importance_nperm=100, BDNN_mean_shap_per_group=False, edge_indicator=False, tT=1.0, nT=5, tQ=[1.2, 1.2], tR=1.2, tS=1.0, fR=0.5, fS=0.7, fQ=0.5, tC=[0.2, 0.2, 0.15], fU=[0.02, 0.18, 0], multiR=1, tHP=[1.2, 1.2]"
# dataframe(rep_bdnn_2)
# Out:
#               Key                                              Value  \
# 19      BDNNmodel                                                  1
# 20      BDNNnodes                                             [8, 4]
# 29   BDNNupdate_f                                 [0.05, 0.05, 0.25]
# 67             fU                                    [0.02, 0.18, 0]
# 77     input_data  ['.\data\reptilia_processed_data\reptilia_pyra...
# 78              j                                                  2
# 89             mG                                               True
# 98              n                                          100000000
# 103             p                                               2000
# 120        qShift                    '.\data\Time_bins_ByStages.txt'
# 133             s                                              10000
# 150     translate                                              175.0
# 155            wd                                      '.\reptilia\'
#
# ...

# %%
rep_bdnn_4 = "seed=-1, useCPPlib=1, cite=False, input_data=['./data/reptilia_processed_data/reptilia_pyrate_PyRate.py'], j=4, trait=1, logT=0, N=-1, wd='./reptilia/', out='', singleton=0, frac_sampled_singleton=0, rescale=1, translate=175.0, d='', clade=-1, trait_file='./data/reptilia_processed_data/reptilia_bdnn_trait_file.txt', restore_mcmc='', filter=[inf, 0], filter_taxa='', initDiv=0, PPmodeltest=False, log_marginal_rates=-1, log_sp_q_rates=False, drop_zero=0, drop_internal=False, tree='', sampling=1.0, bdc=False, eqr=False, plot='', plot2='', plot3='', plotRJ='', plotBDNN='', plotBDNN_groups='', plotBDNN_effects='', plotBDNN_transf_features='', BDNN_groups={}, BDNN_interaction='', BDNN_interaction_fix=False, n_prior=100000, plotQ='', grid_plot=0, root_plot=0, min_age_plot=0, tag='', ltt=0, mProb='', BF=[], data_info=False, SE_stats=[], ginput='', combLog='', combLogRJ='', combBDNN='', resample=0, col_tag=[], check_names='', reduceLog='', n=100000000, s=10000, p=2000, b=0, fast_burnin=0, thread=[0, 0], A=4, use_DA=False, r=1, t=0.03, sw=100, M=10, B=1, T=1.0, S=1000, k=10, a=0.3, dpp_f=500, dpp_hp=2.0, dpp_eK=2.0, dpp_grid=1.5, dpp_nB=0, rj_pr=1, rj_Ga=1.5, rj_Gb=3.0, rj_beta=10, rj_dm=0, rj_bd_shift=0.5, se_gibbs=False, pL=[1.1, 1.1], pM=[1.1, 1.1], pP=[1.5, 1.1], pS=2.5, pC=1, cauchy=[-1, -1], min_dt=1.0, mHPP=False, mL=1, mM=1, mC=False, mCov=0, mG=True, mPoiD=False, mBirth=-1, mDeath=False, mBDI=-1, ncat=4, fixShift='./data/Time_bins_ByStages.txt', qShift='./data/Time_bins_ByStages.txt', fixSE='', ADE=0, discrete=False, twotrait=False, bound=[inf, 0], partialBD=False, edgeShift=[inf, 0], qFilter=1, FBDrange=0, BDNNmodel=1, BDNNnodes=[16, 8], BDNNfadlad=0, BDNNtimetrait=-1, BDNNconstbaseline=1, BDNNoutputfun=1, BDNNactfun=5, BDNNprior=1, BDNNreg=[1.0], BDNNblockmodel=False, BDNNtimevar=['./data/env_vars.txt'], BDNNtimevar_q='', BDNNads=-1.0, BDNNpath_taxon_time_tables=['', ''], BDNNexport_taxon_time_tables=False, BDNNupdate_se_f=[0.6], BDNNupdate_f=[0.1], BDNNdd=False, BDNNpklfile='', BDNN_pred_importance='', BDNN_nsim_expected_cv=100, BDNN_pred_importance_interaction=True, BDNN_pred_importance_window_size=[-1.0], BDNN_pred_importance_nperm=100, BDNN_mean_shap_per_group=False, edge_indicator=False, tT=1.0, nT=5, tQ=[1.2, 1.2], tR=1.2, tS=1.0, fR=0.5, fS=0.7, fQ=0.5, tC=[0.2, 0.2, 0.15], fU=[0.02, 0.18, 0], multiR=1, tHP=[1.2, 1.2]"
dataframe(rep_bdnn_4)
# Out:
#              Key                                              Value  \
# 19     BDNNmodel                                                  1
# 27   BDNNtimevar                            ['./data/env_vars.txt']
# 67            fU                                    [0.02, 0.18, 0]
# 72      fixShift                    './data/Time_bins_ByStages.txt'
# 77    input_data  ['./data/reptilia_processed_data/reptilia_pyra...
# 78             j                                                  4
# 89            mG                                               True
# 98             n                                          100000000
# 103            p                                               2000
# 120       qShift                    './data/Time_bins_ByStages.txt'
# 133            s                                              10000
# 149   trait_file  './data/reptilia_processed_data/reptilia_bdnn_...
# 150    translate                                              175.0
# ...

# %%
rep_bdnn_5 = "seed=-1, useCPPlib=1, cite=False, input_data=['./data/reptilia_processed_data/reptilia_pyrate_PyRate.py'], j=5, trait=1, logT=0, N=-1, wd='./reptilia/', out='', singleton=0, frac_sampled_singleton=0, rescale=1, translate=175.0, d='', clade=-1, trait_file='./data/reptilia_processed_data/reptilia_bdnn_trait_file.txt', restore_mcmc='', filter=[inf, 0], filter_taxa='', initDiv=0, PPmodeltest=False, log_marginal_rates=-1, log_sp_q_rates=False, drop_zero=0, drop_internal=False, tree='', sampling=1.0, bdc=False, eqr=False, plot='', plot2='', plot3='', plotRJ='', plotBDNN='', plotBDNN_groups='', plotBDNN_effects='', plotBDNN_transf_features='', BDNN_groups={}, BDNN_interaction='', BDNN_interaction_fix=False, n_prior=100000, plotQ='', grid_plot=0, root_plot=0, min_age_plot=0, tag='', ltt=0, mProb='', BF=[], data_info=False, SE_stats=[], ginput='', combLog='', combLogRJ='', combBDNN='', resample=0, col_tag=[], check_names='', reduceLog='', n=100000000, s=10000, p=2000, b=0, fast_burnin=0, thread=[2, 0], A=4, use_DA=False, r=1, t=0.03, sw=100, M=10, B=1, T=1.0, S=1000, k=10, a=0.3, dpp_f=500, dpp_hp=2.0, dpp_eK=2.0, dpp_grid=1.5, dpp_nB=0, rj_pr=1, rj_Ga=1.5, rj_Gb=3.0, rj_beta=10, rj_dm=0, rj_bd_shift=0.5, se_gibbs=False, pL=[1.1, 1.1], pM=[1.1, 1.1], pP=[1.5, 1.1], pS=2.5, pC=1, cauchy=[-1, -1], min_dt=1.0, mHPP=False, mL=1, mM=1, mC=False, mCov=0, mG=True, mPoiD=False, mBirth=-1, mDeath=False, mBDI=-1, ncat=4, fixShift='./data/Time_bins_ByStages.txt', qShift='./data/Time_bins_ByStages.txt', fixSE='', ADE=0, discrete=False, twotrait=False, bound=[inf, 0], partialBD=False, edgeShift=[inf, 0], qFilter=1, FBDrange=0, BDNNmodel=1, BDNNnodes=[16, 8], BDNNfadlad=0, BDNNtimetrait=-1, BDNNconstbaseline=1, BDNNoutputfun=1, BDNNactfun=5, BDNNprior=1, BDNNreg=[1.0], BDNNblockmodel=False, BDNNtimevar=['./data/env_vars.txt'], BDNNtimevar_q='', BDNNads=-1.0, BDNNpath_taxon_time_tables=['', ''], BDNNexport_taxon_time_tables=False, BDNNupdate_se_f=[0.6], BDNNupdate_f=[0.1], BDNNdd=False, BDNNpklfile='', BDNN_pred_importance='', BDNN_nsim_expected_cv=100, BDNN_pred_importance_interaction=True, BDNN_pred_importance_window_size=[-1.0], BDNN_pred_importance_nperm=100, BDNN_mean_shap_per_group=False, edge_indicator=False, tT=1.0, nT=5, tQ=[1.2, 1.2], tR=1.2, tS=1.0, fR=0.5, fS=0.7, fQ=0.5, tC=[0.2, 0.2, 0.15], fU=[0.02, 0.18, 0], multiR=1, tHP=[1.2, 1.2]"
dataframe(rep_bdnn_5)
# Out:
#              Key                                              Value  \
# 19     BDNNmodel                                                  1
# 27   BDNNtimevar                            ['./data/env_vars.txt']
# 67            fU                                    [0.02, 0.18, 0]
# 72      fixShift                    './data/Time_bins_ByStages.txt'
# 77    input_data  ['./data/reptilia_processed_data/reptilia_pyra...
# 78             j                                                  5
# 89            mG                                               True
# 98             n                                          100000000
# 103            p                                               2000
# 120       qShift                    './data/Time_bins_ByStages.txt'
# 133            s                                              10000
# 147       thread                                             [2, 0]
# 149   trait_file  './data/reptilia_processed_data/reptilia_bdnn_...
# ...

# %%
tem_mcmc_predictors_covar_1 = "seed=-1, useCPPlib=1, cite=False, input_data=['.\\data\\temnospondyli_processed_data\\temnospondyli_pyrate_PyRate.py'], j=1, trait=1, logT=0, N=-1, wd='', out='', singleton=0, frac_sampled_singleton=0, rescale=1, translate=0, d='', clade=-1, trait_file='.\\data\\temnospondyli_processed_data\\temnospondyli_bdnn_trait_file.txt', restore_mcmc='', filter=[inf, 0], filter_taxa='', initDiv=0, PPmodeltest=False, log_marginal_rates=-1, log_sp_q_rates=False, drop_zero=0, drop_internal=False, tree='', sampling=1.0, bdc=False, eqr=False, plot='', plot2='', plot3='', plotRJ='', plotBDNN='', plotBDNN_groups='', plotBDNN_effects='', plotBDNN_transf_features='', BDNN_groups={}, BDNN_interaction='', BDNN_interaction_fix=False, n_prior=100000, plotQ='', grid_plot=0, root_plot=0, min_age_plot=0, tag='', ltt=0, mProb='', BF=[], data_info=False, SE_stats=[], ginput='', combLog='', combLogRJ='', combBDNN='', resample=0, col_tag=[], check_names='', reduceLog='', n=100000000, s=10000, p=1000, b=0, fast_burnin=0, thread=[0, 0], A=4, use_DA=False, r=1, t=0.03, sw=100, M=10, B=1, T=1.0, S=1000, k=10, a=0.3, dpp_f=500, dpp_hp=2.0, dpp_eK=2.0, dpp_grid=1.5, dpp_nB=0, rj_pr=1, rj_Ga=1.5, rj_Gb=3.0, rj_beta=10, rj_dm=0, rj_bd_shift=0.5, se_gibbs=False, pL=[1.1, 1.1], pM=[1.1, 1.1], pP=[1.5, 1.1], pS=2.5, pC=0.0, cauchy=[-1, -1], min_dt=1.0, mHPP=False, mL=1, mM=1, mC=False, mCov=5, mG=False, mPoiD=False, mBirth=-1, mDeath=False, mBDI=-1, ncat=4, fixShift='', qShift='', fixSE='', ADE=0, discrete=False, twotrait=False, bound=[inf, 0], partialBD=False, edgeShift=[inf, 0], qFilter=1, FBDrange=0, BDNNmodel=0, BDNNnodes=[16, 8], BDNNfadlad=0, BDNNtimetrait=-1, BDNNconstbaseline=1, BDNNoutputfun=1, BDNNactfun=5, BDNNprior=1, BDNNreg=[1.0], BDNNblockmodel=False, BDNNtimevar=[''], BDNNtimevar_q='', BDNNads=-1.0, BDNNpath_taxon_time_tables=['', ''], BDNNexport_taxon_time_tables=False, BDNNupdate_se_f=[0.6], BDNNupdate_f=[0.1], BDNNdd=False, BDNNpklfile='', BDNN_pred_importance='', BDNN_nsim_expected_cv=100, BDNN_pred_importance_interaction=True, BDNN_pred_importance_window_size=[-1.0], BDNN_pred_importance_nperm=100, BDNN_mean_shap_per_group=False, edge_indicator=False, tT=1.0, nT=5, tQ=[1.2, 1.2], tR=1.2, tS=1.0, fR=0.5, fS=0.7, fQ=0.5, tC=[0.2, 0.2, 0.15], fU=[0.02, 0.18, 0.08], multiR=1, tHP=[1.2, 1.2]"
tem_mcmc_predictors_covar_7 = "seed=-1, useCPPlib=1, cite=False, input_data=['./data/temnospondyli_processed_data/temnospondyli_pyrate_PyRate.py'], j=7, trait=1, logT=0, N=-1, wd='./temnospondyli/', out='', singleton=0, frac_sampled_singleton=0, rescale=1, translate=0, d='', clade=-1, trait_file='./data/temnospondyli_processed_data/temnospondyli_bdnn_trait_file.txt', restore_mcmc='', filter=[inf, 0], filter_taxa='', initDiv=0, PPmodeltest=False, log_marginal_rates=-1, log_sp_q_rates=False, drop_zero=0, drop_internal=False, tree='', sampling=1.0, bdc=False, eqr=False, plot='', plot2='', plot3='', plotRJ='', plotBDNN='', plotBDNN_groups='', plotBDNN_effects='', plotBDNN_transf_features='', BDNN_groups={}, BDNN_interaction='', BDNN_interaction_fix=False, n_prior=100000, plotQ='', grid_plot=0, root_plot=0, min_age_plot=0, tag='', ltt=0, mProb='', BF=[], data_info=False, SE_stats=[], ginput='', combLog='', combLogRJ='', combBDNN='', resample=0, col_tag=[], check_names='', reduceLog='', n=100000000, s=10000, p=1000, b=0, fast_burnin=0, thread=[2, 0], A=4, use_DA=False, r=2, t=0.03, sw=100, M=10, B=1, T=1.0, S=1000, k=10, a=0.3, dpp_f=500, dpp_hp=2.0, dpp_eK=2.0, dpp_grid=1.5, dpp_nB=0, rj_pr=1, rj_Ga=1.5, rj_Gb=3.0, rj_beta=10, rj_dm=0, rj_bd_shift=0.5, se_gibbs=False, pL=[1.1, 1.1], pM=[1.1, 1.1], pP=[1.5, 1.1], pS=2.5, pC=0.0, cauchy=[-1, -1], min_dt=1.0, mHPP=False, mL=1, mM=1, mC=False, mCov=5, mG=False, mPoiD=False, mBirth=-1, mDeath=False, mBDI=-1, ncat=4, fixShift='', qShift='', fixSE='', ADE=0, discrete=False, twotrait=False, bound=[inf, 0], partialBD=False, edgeShift=[inf, 0], qFilter=1, FBDrange=0, BDNNmodel=0, BDNNnodes=[16, 8], BDNNfadlad=0, BDNNtimetrait=-1, BDNNconstbaseline=1, BDNNoutputfun=1, BDNNactfun=5, BDNNprior=1, BDNNreg=[1.0], BDNNblockmodel=False, BDNNtimevar=[''], BDNNtimevar_q='', BDNNads=-1.0, BDNNpath_taxon_time_tables=['', ''], BDNNexport_taxon_time_tables=False, BDNNupdate_se_f=[0.6], BDNNupdate_f=[0.1], BDNNdd=False, BDNNpklfile='', BDNN_pred_importance='', BDNN_nsim_expected_cv=100, BDNN_pred_importance_interaction=True, BDNN_pred_importance_window_size=[-1.0], BDNN_pred_importance_nperm=100, BDNN_mean_shap_per_group=False, edge_indicator=False, tT=1.0, nT=5, tQ=[1.2, 1.2], tR=1.2, tS=1.0, fR=0.5, fS=0.7, fQ=0.5, tC=[0.2, 0.2, 0.15], fU=[0.02, 0.18, 0.08], multiR=1, tHP=[1.2, 1.2]"

# %%
dataframe(tem_mcmc_predictors_covar_1)
# Out:
#                             Key  \
# 3                    input_data
# 16                   trait_file
# 60                            n
# 61                            s
# 93                           pC
# 100                        mCov
# 128                 BDNNtimevar
# 131  BDNNpath_taxon_time_tables
#
#                                                  Value Default Value  \
# 3    ['.\data\temnospondyli_processed_data\temnospo...            []
# 16   '.\data\temnospondyli_processed_data\temnospon...            ''
# 60                                           100000000      10000000
# 61                                               10000          1000
# 93                                                 0.0             1
# 100                                                  5             0
# 128                                               ['']            ''
# 131                                           ['', '']          [, ]
#
#      Different
# 3         True
# ...

# %%
dataframe(tem_mcmc_predictors_covar_7)
# Out:
#                             Key  \
# 3                    input_data
# 4                             j
# 8                            wd
# 16                   trait_file
# 60                            n
# 61                            s
# 65                       thread
# 68                            r
# 93                           pC
# 100                        mCov
# 128                 BDNNtimevar
# 131  BDNNpath_taxon_time_tables
#
#                                                  Value Default Value  \
# 3    ['./data/temnospondyli_processed_data/temnospo...            []
# 4                                                    7             1
# 8                                   './temnospondyli/'            ''
# 16   './data/temnospondyli_processed_data/temnospon...            ''
# 60                                           100000000      10000000
# 61                                               10000          1000
# ...

# %% [markdown]
# ## Reptilia Thauffe

# %%
namespace1 = "seed=-1, useCPPlib=1, cite=False, input_data=['reptilia/Reptilia_cleaned_pyrate_input_PyRate.py'], j=1, trait=1, logT=0, N=-1, wd='', out='', singleton=0, frac_sampled_singleton=0, rescale=1, translate=0, d='', clade=-1, trait_file='data/Reptilia_ohe_per_species.txt', restore_mcmc='', filter=[inf, 0], filter_taxa='', initDiv=0, PPmodeltest=False, log_marginal_rates=-1, log_sp_q_rates=False, drop_zero=0, drop_internal=False, tree='', sampling=1.0, bdc=False, eqr=False, plot='', plot2='', plot3='', plotRJ='', plotBDNN='', plotBDNN_groups='', plotBDNN_effects='', plotBDNN_transf_features='', BDNN_groups={}, BDNN_interaction='', BDNN_interaction_fix=False, n_prior=100000, plotQ='', grid_plot=0, root_plot=0, min_age_plot=0, tag='', ltt=0, mProb='', BF=[], data_info=False, SE_stats=[], ginput='', combLog='', combLogRJ='', combBDNN='', resample=0, col_tag=[], check_names='', reduceLog='', n=20000000, s=20000, p=1000, b=0, fast_burnin=0, thread=[0, 0], A=0, use_DA=False, r=1, t=0.03, sw=100, M=10, B=1, T=1.0, S=1000, k=10, a=0.3, dpp_f=500, dpp_hp=2.0, dpp_eK=2.0, dpp_grid=1.5, dpp_nB=0, rj_pr=1, rj_Ga=1.5, rj_Gb=3.0, rj_beta=10, rj_dm=0, rj_bd_shift=0.5, se_gibbs=False, pL=[1.1, 1.1], pM=[1.1, 1.1], pP=[1.5, 1.1], pS=2.5, pC=1, cauchy=[-1, -1], min_dt=1.0, mHPP=False, mL=1, mM=1, mC=False, mCov=0, mG=False, mPoiD=False, mBirth=-1, mDeath=False, mBDI=-1, ncat=4, fixShift='data/Time_bins_ByStages.txt', qShift='data/Time_bins_ByStages.txt', fixSE='', ADE=0, discrete=False, twotrait=False, bound=[inf, 0], partialBD=False, edgeShift=[inf, 0], qFilter=1, FBDrange=0, BDNNmodel=1, BDNNnodes=[8, 4], BDNNfadlad=0, BDNNtimetrait=0.003353462773084001, BDNNconstbaseline=1, BDNNoutputfun=1, BDNNactfun=5, BDNNprior=1, BDNNreg=[1.0], BDNNblockmodel=False, BDNNtimevar='', BDNNtimevar_q='', BDNNads=-1.0, BDNNpath_taxon_time_tables=['', ''], BDNNexport_taxon_time_tables=False, BDNNupdate_se_f=[0.6], BDNNupdate_f=[0.1], BDNNdd=False, BDNNpklfile='', BDNN_pred_importance='', BDNN_nsim_expected_cv=100, BDNN_pred_importance_interaction=True, BDNN_pred_importance_window_size=[-1.0], BDNN_pred_importance_nperm=100, BDNN_mean_shap_per_group=False, edge_indicator=False, tT=1.0, nT=5, tQ=[1.2, 1.2], tR=1.2, tS=1.0, fR=0.5, fS=0.7, fQ=0.5, tC=[0.2, 0.2, 0.15], fU=[0.02, 0.18, 0], multiR=1, tHP=[1.2, 1.2]"

# %%
dataframe(namespace1)
# Out:
#                             Key  \
# 3                    input_data
# 16                   trait_file
# 60                            n
# 61                            s
# 66                            A
# 107                    fixShift
# 108                      qShift
# 118                   BDNNmodel
# 119                   BDNNnodes
# 121               BDNNtimetrait
# 131  BDNNpath_taxon_time_tables
# 153                          fU
#
#                                                  Value       Default Value  \
# 3    ['reptilia/Reptilia_cleaned_pyrate_input_PyRat...                  []
# 16                 'data/Reptilia_ohe_per_species.txt'                  ''
# 60                                            20000000            10000000
# 61                                               20000                1000
# 66                                                   0                   4
# 107                      'data/Time_bins_ByStages.txt'                  ''
# ...

# %%
namespace_gibbs = "seed=123, useCPPlib=1, cite=False, input_data=['/home/ubuntu/BDNN_Arielli/reptilia/Reptilia_cleaned_pyrate_input_PyRate.py'], j=1, trait=1, logT=0, N=-1, wd='', out='', singleton=0, frac_sampled_singleton=0, rescale=1, translate=-175.0, d='', clade=-1, trait_file='/home/ubuntu/BDNN_Arielli/data/Reptilia_ohe_per_species.txt', restore_mcmc='', filter=[inf, 0], filter_taxa='', initDiv=0, PPmodeltest=False, log_marginal_rates=-1, log_sp_q_rates=False, drop_zero=0, drop_internal=False, tree='', sampling=1.0, bdc=False, eqr=False, plot='', plot2='', plot3='', plotRJ='', plotBDNN='', plotBDNN_groups='', plotBDNN_effects='', plotBDNN_transf_features='', BDNN_groups={}, BDNN_interaction='', BDNN_interaction_fix=False, n_prior=100000, plotQ='', grid_plot=0, root_plot=0, min_age_plot=0, tag='', ltt=0, mProb='', BF=[], data_info=False, SE_stats=[], ginput='', combLog='', combLogRJ='', combBDNN='', resample=0, col_tag=[], check_names='', reduceLog='', n=100000001, s=20000, p=1000000, b=0, fast_burnin=0, thread=[0, 0], A=4, use_DA=False, r=1, t=0.03, sw=100, M=10, B=1, T=1.0, S=1000, k=10, a=0.3, dpp_f=500, dpp_hp=2.0, dpp_eK=2.0, dpp_grid=1.5, dpp_nB=0, rj_pr=1, rj_Ga=1.5, rj_Gb=3.0, rj_beta=10, rj_dm=0, rj_bd_shift=0.5, se_gibbs=True, pL=[1.1, 1.1], pM=[1.1, 1.1], pP=[1.5, 1.1], pS=2.5, pC=1, cauchy=[-1, -1], min_dt=1.0, mHPP=False, mL=1, mM=1, mC=False, mCov=0, mG=False, mPoiD=False, mBirth=-1, mDeath=False, mBDI=-1, ncat=4, fixShift='/home/ubuntu/BDNN_Arielli/data/Time_bins_CrossStage.txt', qShift='/home/ubuntu/BDNN_Arielli/data/Time_bins_ByStages.txt', fixSE='', ADE=0, discrete=False, twotrait=False, bound=[inf, 0], partialBD=False, edgeShift=[inf, 0], qFilter=1, FBDrange=0, BDNNmodel=1, BDNNnodes=[16, 8], BDNNfadlad=0, BDNNtimetrait=0.008116934177142753, BDNNconstbaseline=1, BDNNoutputfun=1, BDNNactfun=5, BDNNprior=1, BDNNreg=[1.0], BDNNblockmodel=False, BDNNtimevar='', BDNNtimevar_q='', BDNNads=-1.0, BDNNpath_taxon_time_tables=['', ''], BDNNexport_taxon_time_tables=False, BDNNupdate_se_f=[0.6], BDNNupdate_f=[0.1], BDNNdd=False, BDNNpklfile='', BDNN_pred_importance='', BDNN_nsim_expected_cv=100, BDNN_pred_importance_interaction=True, BDNN_pred_importance_window_size=[-1.0], BDNN_pred_importance_nperm=100, BDNN_mean_shap_per_group=False, edge_indicator=False, tT=1.0, nT=5, tQ=[1.2, 1.2], tR=1.2, tS=1.0, fR=0.5, fS=0.7, fQ=0.5, tC=[0.2, 0.2, 0.15], fU=[0.02, 0.18, 0], multiR=1, tHP=[1.2, 1.2]"

# %%
dataframe(namespace_gibbs)
# Out:
#                             Key  \
# 0                          seed
# 3                    input_data
# 13                    translate
# 16                   trait_file
# 60                            n
# 61                            s
# 62                            p
# 88                     se_gibbs
# 107                    fixShift
# 108                      qShift
# 118                   BDNNmodel
# 121               BDNNtimetrait
# 131  BDNNpath_taxon_time_tables
# 153                          fU
#
#                                                  Value       Default Value  \
# 0                                                  123                  -1
# 3    ['/home/ubuntu/BDNN_Arielli/reptilia/Reptilia_...                  []
# 13                                              -175.0                   0
# 16   '/home/ubuntu/BDNN_Arielli/data/Reptilia_ohe_p...                  ''
# 60                                           100000001            10000000
# ...

# %%
# Covar 2

namespace_covar2 = "seed=-1, useCPPlib=1, cite=False, input_data=['reptilia/Reptilia_cleaned_pyrate_input_PyRate.py'], j=1, trait=1, logT=1, N=-1, wd='', out='_200_run_1', singleton=0, frac_sampled_singleton=0, rescale=1, translate=0, d='', clade=-1, trait_file='data/reptilia/Reptilia_species_traits.txt', restore_mcmc='', filter=[inf, 0], filter_taxa='', initDiv=0, PPmodeltest=False, log_marginal_rates=-1, log_sp_q_rates=False, drop_zero=0, drop_internal=False, tree='', sampling=1.0, bdc=False, eqr=False, plot='', plot2='', plot3='', plotRJ='', plotBDNN='', plotBDNN_groups='', plotBDNN_effects='', plotBDNN_transf_features='', BDNN_groups={}, BDNN_interaction='', BDNN_interaction_fix=False, n_prior=100000, plotQ='', grid_plot=0, root_plot=0, min_age_plot=0, tag='', ltt=0, mProb='', BF=[], data_info=False, SE_stats=[], ginput='', combLog='', combLogRJ='', combBDNN='', resample=0, col_tag=[], check_names='', reduceLog='', n=200000000, s=20000, p=1000, b=0, fast_burnin=0, thread=[0, 0], A=4, use_DA=False, r=1, t=0.03, sw=100, M=10, B=1, T=1.0, S=1000, k=10, a=0.3, dpp_f=500, dpp_hp=2.0, dpp_eK=2.0, dpp_grid=1.5, dpp_nB=0, rj_pr=1, rj_Ga=1.5, rj_Gb=3.0, rj_beta=10, rj_dm=0, rj_bd_shift=0.5, se_gibbs=False, pL=[1.1, 1.1], pM=[1.1, 1.1], pP=[1.5, 1.1], pS=2.5, pC=0.0, cauchy=[-1, -1], min_dt=1.0, mHPP=False, mL=1, mM=1, mC=False, mCov=5, mG=False, mPoiD=False, mBirth=-1, mDeath=False, mBDI=-1, ncat=4, fixShift='data/Time_bins_ByStages.txt', qShift='data/Time_bins_ByStages.txt', fixSE='', ADE=0, discrete=False, twotrait=False, bound=[inf, 0], partialBD=False, edgeShift=[inf, 0], qFilter=1, FBDrange=0, BDNNmodel=0, BDNNnodes=[16, 8], BDNNfadlad=0, BDNNtimetrait=-1, BDNNconstbaseline=1, BDNNoutputfun=1, BDNNactfun=5, BDNNprior=1, BDNNreg=[1.0], BDNNblockmodel=False, BDNNtimevar='', BDNNtimevar_q='', BDNNads=-1.0, BDNNpath_taxon_time_tables=['', ''], BDNNexport_taxon_time_tables=False, BDNNupdate_se_f=[0.6], BDNNupdate_f=[0.1], BDNNdd=False, BDNNpklfile='', BDNN_pred_importance='', BDNN_nsim_expected_cv=100, BDNN_pred_importance_interaction=True, BDNN_pred_importance_window_size=[-1.0], BDNN_pred_importance_nperm=100, BDNN_mean_shap_per_group=False, edge_indicator=False, tT=1.0, nT=5, tQ=[1.2, 1.2], tR=1.2, tS=1.0, fR=0.5, fS=0.7, fQ=0.5, tC=[0.2, 0.2, 0.15], fU=[0.02, 0.18, 0.08], multiR=1, tHP=[1.2, 1.2]"
dataframe(namespace_covar2)
# Out:
#                             Key  \
# 3                    input_data
# 6                          logT
# 9                           out
# 16                   trait_file
# 60                            n
# 61                            s
# 93                           pC
# 100                        mCov
# 107                    fixShift
# 108                      qShift
# 131  BDNNpath_taxon_time_tables
#
#                                                  Value Default Value  \
# 3    ['reptilia/Reptilia_cleaned_pyrate_input_PyRat...            []
# 6                                                    1             0
# 9                                         '_200_run_1'            ''
# 16         'data/reptilia/Reptilia_species_traits.txt'            ''
# 60                                           200000000      10000000
# 61                                               20000          1000
# 93                                                 0.0             1
# ...
